# %% [markdown]
# [Cloud Functions: Qwik Start – konsola](https://www.cloudskillsboost.google/focuses/1763?catalog_rank=%7B%22rank%22%3A1%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23714883)

# %% [markdown]
# ![2023-05-10 13_10_51-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 13_19_13-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 13_44_15-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/functions/docs/calling/http

# %% [markdown]
# ![2023-05-10 14_03_34-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_04_20-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_33_40-Create function – Cloud Functions – qwiklabs-gcp-04-fd0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_12_45-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_34_54-Create function – Cloud Functions – qwiklabs-gcp-04-fd0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_14_31-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_38_11-Functions – Cloud Functions – qwiklabs-gcp-04-fd0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_14_47-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
"message":"Hello World!"

# %% [markdown]
# ![2023-05-10 14_40_07-GCFunction – Cloud Functions – qwiklabs-gcp-04-fd0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_16_21-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_41_27-GCFunction – Cloud Functions – qwiklabs-gcp-04-fd0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_18_25-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_42_58-Functions – Cloud Functions – qwiklabs-gcp-04-fd0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_24_45-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_25_12-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
resource.type="cloud_function" resource.labels.function_name="GCFunction" resource.labels.region="us-central1"
protoPayload.authenticationInfo.principalEmail="student-00-a44a6223d024@qwiklabs.net"

# %% [markdown]
# ![2023-05-10 14_47_25-Logs Explorer – Logging – qwiklabs-gcp-04-fd0… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 14_44_15-Cloud Functions_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

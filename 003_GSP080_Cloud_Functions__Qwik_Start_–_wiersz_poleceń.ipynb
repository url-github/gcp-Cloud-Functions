# %% [markdown]
# [Cloud Functions: Qwik Start – wiersz poleceń](https://www.cloudskillsboost.google/focuses/916?catalog_rank=%7B%22rank%22%3A2%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23714883)

# %% [markdown]
# ![2023-05-10 15_00_06-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 15_01_30-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 15_03_16-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/functions/docs/calling

# %% [markdown]
# ![2023-05-10 15_06_18-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 15_08_14-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 15_08_57-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/pubsub/architecture

# https://cloud.google.com/functions/docs/writing/write-event-driven-functions

# %%
mkdir gcf_hello_world

# %% [markdown]
# ![2023-05-10 15_22_12-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
cd gcf_hello_world

# %% [markdown]
# ![2023-05-10 15_23_07-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
nano index.js

# %% [markdown]
# ![2023-05-10 15_23_52-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
/**
* Działająca w tle funkcja w Cloud Functions wyzwalana przez Pub/Sub.
* Ta funkcja jest eksportowana przez plik index.js i wykonywana, kiedy
* temat aktywatora odbierze wiadomość.
*
* @param {object} data Ładunek zdarzenia.
* @param {object} context Metadane zdarzenia.
*/
exports.helloWorld = (data, context) => {
const pubSubMessage = data;
const name = pubSubMessage.data
    ? Buffer.from(pubSubMessage.data, 'base64').toString() : "Hello World";
console.log(`Moja funkcja w Cloud Functions: ${name}`);
};

# %% [markdown]
# ![2023-05-10 15_27_30-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-12 11_42_23-.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 15_28_06-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gsutil mb -p [PROJECT_ID] gs://[BUCKET_NAME]

# %%
gsutil mb -p qwiklabs-gcp-02-6fe157ac5cd9 gs://exam-958365679

# %% [markdown]
# ![2023-05-10 15_30_18-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud functions deploy helloWorld \
  --stage-bucket exam-958365679 \
  --trigger-topic hello_world \
  --runtime nodejs8

# %% [markdown]
# ![2023-05-10 15_36_26-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-12 11_46_55-.png](data:image/png;base64,...)

# %%
gcloud functions describe helloWorld

# %% [markdown]
# ![2023-05-10 15_37_11-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 15_37_52-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 15_40_30-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
DATA=$(printf 'Hello World!'|base64) && gcloud functions call helloWorld --data '{"data":"'$DATA'"}'

# %% [markdown]
# ![2023-05-10 15_41_13-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-10 15_41_46-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud functions logs read helloWorld

# %% [markdown]
# ![2023-05-10 15_42_49-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-12 08_31_11-Cloud Functions_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)
